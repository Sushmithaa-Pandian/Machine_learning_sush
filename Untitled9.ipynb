# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushmithaa-Pandian/Machine_learning_sush/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
users=pd.read_csv("/content/gdrive/MyDrive/Users.csv")

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
books=pd.read_csv("/content/gdrive/MyDrive/Books.csv")
# Out:
# <ipython-input-4-51729d6f8703>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books=pd.read_csv("/content/gdrive/MyDrive/Books.csv")

# %%
books.drop(['Image-URL-S',	'Image-URL-M',	'Image-URL-L'],axis=1,inplace=True)

# %%
books.head(10)
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
# 5  0399135782                             The Kitchen God's Wife
# 6  0425176428  What If?: The World's Foremost Military Histor...
# 7  0671870432                                    PLEADING GUILTY
# 8  0679425608  Under the Black Flag: The Romance and the Real...
# 9  074322678X            Where You'll Find Me: And Other Stories
#
#             Book-Author Year-Of-Publication                   Publisher
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# ...

# %%
rate=pd.read_csv("/content/gdrive/MyDrive/Ratings.csv")

# %%
rate.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
books.drop_duplicates(keep='last', inplace=True)
books.reset_index(drop = True, inplace = True)

# %%
rate.drop_duplicates(keep='last', inplace=True)
rate.reset_index(drop = True, inplace = True)

# %%
users.drop_duplicates(keep='last', inplace=True)
users.reset_index(drop = True, inplace = True)

# %%
books["Year-Of-Publication"]=books["Year-Of-Publication"].fillna('2000')

# %%
x=users.copy()

# %%
x["Age"].mean()
# Out:
# 34.75143370454978

# %%
users["Age"].fillna("35",inplace=True)

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa    35
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia    35
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom    35

# %%
users.isnull().sum()
# Out:
# User-ID     0
# Location    0
# Age         0
# dtype: int64

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# dtype: int64

# %%
books=books.fillna("Other")

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# dtype: int64

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
rate.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
users.duplicated().sum()
# Out:
# 0

# %%
books.duplicated().sum()
# Out:
# 0

# %%
rate.duplicated().sum()
# Out:
# 0

# %%
dataset = pd.merge(books, rate, on='ISBN', how='inner')
dataset = pd.merge(dataset, users, on='User-ID', how='inner')
dataset.head(30)
# Out:
#           ISBN                                         Book-Title  \
# 0   0195153448                                Classical Mythology
# 1   0002005018                                       Clara Callan
# 2   0060973129                               Decision in Normandy
# 3   0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4   0393045218                             The Mummies of Urumchi
# 5   0399135782                             The Kitchen God's Wife
# 6   0425176428  What If?: The World's Foremost Military Histor...
# 7   0671870432                                    PLEADING GUILTY
# 8   0679425608  Under the Black Flag: The Romance and the Real...
# 9   074322678X            Where You'll Find Me: And Other Stories
# 10  0771074670                        Nights Below Station Street
# 11  080652121X  Hitler's Secret Bankers: The Myth of Swiss Neu...
# 12  0887841740                                 The Middle Stories
# ...

# %%
dnew=dataset.drop(["Year-Of-Publication","Location"],axis=1)

# %%
dnew.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author                   Publisher  User-ID  Book-Rating  \
# 0    Mark P. O. Morford     Oxford University Press        2            0
# 1  Richard Bruce Wright       HarperFlamingo Canada        8            5
# 2          Carlo D'Este             HarperPerennial        8            0
# 3      Gina Bari Kolata        Farrar Straus Giroux        8            0
# 4       E. J. W. Barber  W. W. Norton &amp; Company        8            0
#
#     Age
# 0  18.0
# 1    35
# 2    35
# 3    35
# 4    35

# %%
dnew.duplicated().sum()
# Out:
# 0

# %%
dnew.shape
# Out:
# (1031136, 7)

# %%
dnew.sort_values('Book-Rating',ascending=False,inplace=True)

# %%
dnew.head()
# Out:
#               ISBN                                         Book-Title  \
# 158414  0394552989                            The Adrian Mole Diaries
# 688948  0446605484                  Roses Are Red (Alex Cross Novels)
# 200432  0307960374          Seven Little Postmen (Little Golden Book)
# 539911  0374126178  Collected Poems: Edited by Frank Bidart and Da...
# 731866  0380788624                                      Cryptonomicon
#
#                 Book-Author                  Publisher  User-ID  Book-Rating  \
# 158414         Sue Townsend             Pub Group West    99946           10
# 688948      James Patterson              Warner Vision   207750           10
# 200432  Margaret Wise Brown               Golden Books     6251           10
# 539911        Robert Lowell  Farrar, Straus and Giroux    76499           10
# 731866      Neal Stephenson                  Perennial   159137           10
#
#          Age
# 158414    35
# 688948    35
# 200432  32.0
# 539911    35
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
import re
import random
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
dnew1=dnew[dnew['Book-Rating']!=0]

# %%
dnew1.shape
# Out:
# (383842, 7)

# %%
plt.figure(figsize=(10,6))
sns.countplot(y="Book-Author", data=books,order=books['Book-Author'].value_counts().index[0:20])
plt.title("No of books by an author")
# Out:
# Text(0.5, 1.0, 'No of books by an author')

# %%
plt.figure(figsize=(10,6))
sns.countplot(y="Book-Title", data=dnew1, order=dnew1['Book-Title'].value_counts().index[0:20])
plt.title("Number of Ratings for a book")
# Out:
# Text(0.5, 1.0, 'Number of Ratings for a book')

# %%
df=dnew1.copy()
df.dropna(inplace=True)
df.reset_index(drop=True,inplace=True)
df["Book-Title"]=df["Book-Title"].apply(lambda x: re.sub("[\W_]+"," ",x).strip())
df.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0394552989                            The Adrian Mole Diaries
# 1  0446605484                    Roses Are Red Alex Cross Novels
# 2  0307960374            Seven Little Postmen Little Golden Book
# 3  0374126178  Collected Poems Edited by Frank Bidart and Dav...
# 4  0380788624                                      Cryptonomicon
#
#            Book-Author                  Publisher  User-ID  Book-Rating   Age
# 0         Sue Townsend             Pub Group West    99946           10    35
# 1      James Patterson              Warner Vision   207750           10    35
# 2  Margaret Wise Brown               Golden Books     6251           10  32.0
# 3        Robert Lowell  Farrar, Straus and Giroux    76499           10    35
# 4      Neal Stephenson                  Perennial   159137           10  42.0

# %%
def content_based(bookTitle):
    bookTitle=str(bookTitle)

    if bookTitle in dnew1["Book-Title"].values:
        rating_count=pd.DataFrame(dnew1["Book-Title"].value_counts())
        rare_books=rating_count[rating_count["Book-Title"]>=10].index
        common_books=dnew1[~dnew1["Book-Title"].isin(rare_books)]

        if bookTitle in rare_books:
            most_common=pd.Series(common_books["Book-Title"].unique()).sample(3).values
            print("No Recommendations for this Book \n ")
            print("Here are some books you might enjoy: \n ")
            print("{}".format(most_common[0]), "\n")
            print("{}".format(most_common[1]), "\n")
            print("{}".format(most_common[2]), "\n")
        else:
            common_books=common_books.drop_duplicates(subset=["Book-Title"])
            common_books.reset_index(inplace=True)
            common_books["index"]=[i for i in range(common_books.shape[0])]
            targets=["Book-Title","Book-Author","Publisher"]
            common_books["all_features"] = [" ".join(common_books[targets].iloc[i,].values) for i in range(common_books[targets].shape[0])]
            vectorizer=CountVectorizer()
            common_booksVector=vectorizer.fit_transform(common_books["all_features"])
            similarity=cosine_similarity(common_booksVector)
            index=common_books[common_books["Book-Title"]==bookTitle]["index"].values[0]
            similar_books=list(enumerate(similarity[index]))
            similar_booksSorted=sorted(similar_books,key=lambda x:x[1],reverse=True)[1:6]
            books=[]
            for i in range(len(similar_booksSorted)):

                books.append(common_books[common_books["index"]==similar_booksSorted[i][0]]["Book-Title"].item())
            print("Here are books you may like")
            for j in range(len(books)):
              print(books[j])


    else:
        print("Could not find book")

# %%
content_based("Clara Callan")
# Out:
# With Nails the Film Diaries of Richard E
# One
# Samaritan
# The Stargazey: A Richard Jury Mystery (Richard Jury Mysteries (Paperback))
# The Lamorna Wink: A Richard Jury Mystery (Richard Jury Mysteries (Paperback))

# %%
content_based("Circle of Friends")
# Out:
# Legacy of Silence
# Shadows
# Couplehood
# Daybreak
# Promises

# %%
content_based("The Da Vinci Code")
# Out:
# El Codigo Da Vinci / The Da Vinci Code
# Cracking Da Vinci's Code: You've Read the Fiction, Now Read the Facts
# The Da Vinci Legacy
# The Catcher in the Rye
# The Cat and the Curmudgeon
